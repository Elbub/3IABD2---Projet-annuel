# %%
from serpapi import GoogleSearch
import json
import requests
from environs import Env
from datetime import datetime


env = Env()
env.read_env("../../.env")
# Clé d'API SerpApi
API_KEY = env.str("SERPAPI_KEY")

def get_images(api_key, search: str, page: int = 1, pays_requete: str = "US"):
    # Paramètres de recherche
    params = {
        "api_key": api_key,
        "q": search,
        "engine": "google_images",
        "cc": pays_requete,
        "ijn": page,  # ce paramètre correspond à la page de google image à télécharger
    }

    # Appel de l'API SerpApi
    search = GoogleSearch(params)  # nous donne la réponse de l'appel api

    results = search.get_dict()  # JSON -> Python dict
    json_object = json.dumps(results, indent=4)

    with open("search_result.json", "w") as outfile:
        outfile.write(json_object)

    return results



def store_images(json_file, destination_folder: str):
    day = datetime.now()

    with open(json_file) as f:
        results = json.load(f)

    # Dossier de destination pour enregistrer les images
    destination_folder = f"../photos_brutes/{destination_folder}"

    # headers pour passer dans certains cas une sécurité qui bloque les algo de scrapping
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }
    if "error" not in results and "images_results" in results:
        images = results["images_results"]
        for i, image in enumerate(images):
            image_url = image["original"]
            if image_url:
                # num = i + 100 # penser à mettre la bonne centaine ici, cela a pour but de nommer différemment nos images
                file_name = (
                    f"image_{day.strftime('%Y-%m-%d_%H-%M')}_{i}.jpg"  # nom du fichier
                )
                try:
                    response = requests.get(image_url, headers=headers, timeout=10)
                    # Enregistrer l'image dans le dossier de destination
                    if response.status_code == 200:
                        print(f"image : {i}")
                        with open(f"{destination_folder}/{file_name}", "wb") as file:
                            file.write(response.content)
                            print(f"Image enregistrée : {file_name}")
                    else:
                        print(f"Echec du téléchargement de l'image : {image_url}")
                        continue
                except Exception as e:
                    print(e)

# %%
res = get_images(API_KEY, "Les temples d’Angkor", page=2, pays_requete="fr")

# %%
destination_folder = ["rome_grece", "amerique_sud", "asie_sud_est","chateau_europe", "parthenon", "chateau_bodiam", "angkor"]
store_images("search_result.json", destination_folder[6])
print('requete terminée')
# Out:
# image : 0
# Image enregistrée : image_2023-07-08_17-44_0.jpg
# image : 1
# Image enregistrée : image_2023-07-08_17-44_1.jpg
# image : 2
# Image enregistrée : image_2023-07-08_17-44_2.jpg
# image : 3
# Image enregistrée : image_2023-07-08_17-44_3.jpg
# image : 4
# Image enregistrée : image_2023-07-08_17-44_4.jpg
# image : 5
# Image enregistrée : image_2023-07-08_17-44_5.jpg
# image : 6
# Image enregistrée : image_2023-07-08_17-44_6.jpg
# image : 7
# Image enregistrée : image_2023-07-08_17-44_7.jpg
# image : 8
# Image enregistrée : image_2023-07-08_17-44_8.jpg
# image : 9
# Image enregistrée : image_2023-07-08_17-44_9.jpg
# image : 10
# Image enregistrée : image_2023-07-08_17-44_10.jpg
# image : 11
# Image enregistrée : image_2023-07-08_17-44_11.jpg
# image : 12
# Image enregistrée : image_2023-07-08_17-44_12.jpg
# image : 13
# Image enregistrée : image_2023-07-08_17-44_13.jpg
# image : 14
# Image enregistrée : image_2023-07-08_17-44_14.jpg
# image : 15
# Image enregistrée : image_2023-07-08_17-44_15.jpg
# image : 16
# Image enregistrée : image_2023-07-08_17-44_16.jpg
# Echec du téléchargement de l'image : https://i0.wp.com/siemreap.eu/wp-content/uploads/2014/07/Angkor-Wat1.jpg
# image : 18
# Image enregistrée : image_2023-07-08_17-44_18.jpg
# image : 19
# Image enregistrée : image_2023-07-08_17-44_19.jpg
# image : 20
# Image enregistrée : image_2023-07-08_17-44_20.jpg
# image : 21
# Image enregistrée : image_2023-07-08_17-44_21.jpg
# image : 22
# Image enregistrée : image_2023-07-08_17-44_22.jpg
# image : 23
# Image enregistrée : image_2023-07-08_17-44_23.jpg
# image : 24
# Image enregistrée : image_2023-07-08_17-44_24.jpg
# image : 25
# Image enregistrée : image_2023-07-08_17-44_25.jpg
# image : 26
# Image enregistrée : image_2023-07-08_17-44_26.jpg
# image : 27
# Image enregistrée : image_2023-07-08_17-44_27.jpg
# image : 28
# Image enregistrée : image_2023-07-08_17-44_28.jpg
# image : 29
# Image enregistrée : image_2023-07-08_17-44_29.jpg
# image : 30
# Image enregistrée : image_2023-07-08_17-44_30.jpg
# image : 31
# Image enregistrée : image_2023-07-08_17-44_31.jpg
# image : 32
# Image enregistrée : image_2023-07-08_17-44_32.jpg
# image : 33
# Image enregistrée : image_2023-07-08_17-44_33.jpg
# image : 34
# Image enregistrée : image_2023-07-08_17-44_34.jpg
# image : 35
# Image enregistrée : image_2023-07-08_17-44_35.jpg
# image : 36
# Image enregistrée : image_2023-07-08_17-44_36.jpg
# image : 37
# Image enregistrée : image_2023-07-08_17-44_37.jpg
# image : 38
# Image enregistrée : image_2023-07-08_17-44_38.jpg
# image : 39
# Image enregistrée : image_2023-07-08_17-44_39.jpg
# image : 40
# Image enregistrée : image_2023-07-08_17-44_40.jpg
# image : 41
# Image enregistrée : image_2023-07-08_17-44_41.jpg
# image : 42
# Image enregistrée : image_2023-07-08_17-44_42.jpg
# image : 43
# Image enregistrée : image_2023-07-08_17-44_43.jpg
# image : 44
# Image enregistrée : image_2023-07-08_17-44_44.jpg
# image : 45
# Image enregistrée : image_2023-07-08_17-44_45.jpg
# image : 46
# Image enregistrée : image_2023-07-08_17-44_46.jpg
# image : 47
# Image enregistrée : image_2023-07-08_17-44_47.jpg
# image : 48
# Image enregistrée : image_2023-07-08_17-44_48.jpg
# image : 49
# Image enregistrée : image_2023-07-08_17-44_49.jpg
# image : 50
# Image enregistrée : image_2023-07-08_17-44_50.jpg
# image : 51
# Image enregistrée : image_2023-07-08_17-44_51.jpg
# image : 52
# Image enregistrée : image_2023-07-08_17-44_52.jpg
# image : 53
# Image enregistrée : image_2023-07-08_17-44_53.jpg
# image : 54
# Image enregistrée : image_2023-07-08_17-44_54.jpg
# image : 55
# Image enregistrée : image_2023-07-08_17-44_55.jpg
# image : 56
# Image enregistrée : image_2023-07-08_17-44_56.jpg
# image : 57
# Image enregistrée : image_2023-07-08_17-44_57.jpg
# image : 58
# Image enregistrée : image_2023-07-08_17-44_58.jpg
# image : 59
# Image enregistrée : image_2023-07-08_17-44_59.jpg
# image : 60
# Image enregistrée : image_2023-07-08_17-44_60.jpg
# image : 61
# Image enregistrée : image_2023-07-08_17-44_61.jpg
# image : 62
# Image enregistrée : image_2023-07-08_17-44_62.jpg
# image : 63
# Image enregistrée : image_2023-07-08_17-44_63.jpg
# image : 64
# Image enregistrée : image_2023-07-08_17-44_64.jpg
# image : 65
# Image enregistrée : image_2023-07-08_17-44_65.jpg
# image : 66
# Image enregistrée : image_2023-07-08_17-44_66.jpg
# image : 67
# Image enregistrée : image_2023-07-08_17-44_67.jpg
# image : 68
# Image enregistrée : image_2023-07-08_17-44_68.jpg
# image : 69
# Image enregistrée : image_2023-07-08_17-44_69.jpg
# image : 70
# Image enregistrée : image_2023-07-08_17-44_70.jpg
# image : 71
# Image enregistrée : image_2023-07-08_17-44_71.jpg
# image : 72
# Image enregistrée : image_2023-07-08_17-44_72.jpg
# image : 73
# Image enregistrée : image_2023-07-08_17-44_73.jpg
# image : 74
# Image enregistrée : image_2023-07-08_17-44_74.jpg
# image : 75
# Image enregistrée : image_2023-07-08_17-44_75.jpg
# image : 76
# Image enregistrée : image_2023-07-08_17-44_76.jpg
# image : 77
# Image enregistrée : image_2023-07-08_17-44_77.jpg
# image : 78
# Image enregistrée : image_2023-07-08_17-44_78.jpg
# image : 79
# Image enregistrée : image_2023-07-08_17-44_79.jpg
# image : 80
# Image enregistrée : image_2023-07-08_17-44_80.jpg
# image : 81
# Image enregistrée : image_2023-07-08_17-44_81.jpg
# image : 82
# Image enregistrée : image_2023-07-08_17-44_82.jpg
# Echec du téléchargement de l'image : https://library.khmerstudies.org/cgi-bin/koha/opac-image.pl?imagenumber=6050
# image : 84
# Image enregistrée : image_2023-07-08_17-44_84.jpg
# image : 85
# Image enregistrée : image_2023-07-08_17-44_85.jpg
# image : 86
# Image enregistrée : image_2023-07-08_17-44_86.jpg
# image : 87
# Image enregistrée : image_2023-07-08_17-44_87.jpg
# image : 88
# Image enregistrée : image_2023-07-08_17-44_88.jpg
# image : 89
# Image enregistrée : image_2023-07-08_17-44_89.jpg
# image : 90
# Image enregistrée : image_2023-07-08_17-44_90.jpg
# image : 91
# Image enregistrée : image_2023-07-08_17-44_91.jpg
# image : 92
# Image enregistrée : image_2023-07-08_17-44_92.jpg
# image : 93
# Image enregistrée : image_2023-07-08_17-44_93.jpg
# image : 94
# Image enregistrée : image_2023-07-08_17-44_94.jpg
# image : 95
# Image enregistrée : image_2023-07-08_17-44_95.jpg
# image : 96
# Image enregistrée : image_2023-07-08_17-44_96.jpg
# image : 97
# Image enregistrée : image_2023-07-08_17-44_97.jpg
# image : 98
# Image enregistrée : image_2023-07-08_17-44_98.jpg
# image : 99
# Image enregistrée : image_2023-07-08_17-44_99.jpg
# requete terminée
