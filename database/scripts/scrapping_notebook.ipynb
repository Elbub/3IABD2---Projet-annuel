# %%
from serpapi import GoogleSearch
import json
import requests
from environs import Env
from datetime import datetime


env = Env()
env.read_env("../../.env")
# Clé d'API SerpApi
API_KEY = env.str("SERPAPI_KEY")

def get_images(api_key, search: str, page: int = 1, pays_requete: str = "US"):
    # Paramètres de recherche
    params = {
        "api_key": api_key,
        "q": search,
        "engine": "google_images",
        "cc": pays_requete,
        "ijn": page,  # ce paramètre correspond à la page de google image à télécharger
    }

    # Appel de l'API SerpApi
    search = GoogleSearch(params)  # nous donne la réponse de l'appel api

    results = search.get_dict()  # JSON -> Python dict
    json_object = json.dumps(results, indent=4)

    with open("search_result.json", "w") as outfile:
        outfile.write(json_object)

    return results

    store_images(res, destination_folder[0])


def store_images(json_file, destination_folder: str):
    day = datetime.now()

    with open(json_file) as f:
        results = json.load(f)

    # Dossier de destination pour enregistrer les images
    destination_folder = f"../photos_brutes/{destination_folder}"

    # headers pour passer dans certains cas une sécurité qui bloque les algo de scrapping
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }
    if "error" not in results and "images_results" in results:
        images = results["images_results"]
        for i, image in enumerate(images):
            image_url = image["original"]
            if image_url:
                # num = i + 100 # penser à mettre la bonne centaine ici, cela a pour but de nommer différemment nos images
                file_name = (
                    f"image_{day.strftime('%Y-%m-%d_%H-%M')}_{i}.jpg"  # nom du fichier
                )
                try:
                    response = requests.get(image_url, headers=headers, timeout=10)
                    # Enregistrer l'image dans le dossier de destination
                    if response.status_code == 200:
                        print(f"image : {i}")
                        with open(f"{destination_folder}/{file_name}", "wb") as file:
                            file.write(response.content)
                            print(f"Image enregistrée : {file_name}")
                    else:
                        print(f"Echec du téléchargement de l'image : {image_url}")
                        continue
                except Exception as e:
                    print(e)

# %%
res = get_images(API_KEY, "My Son Sanctuary", page=1, pays_requete="fr")

# %%
destination_folder = ["rome_grece", "amerique_sud", "asie_sud_est","chateau_europe"]
store_images("search_result.json", destination_folder[2])
print('requete terminée')
# Out:
# image : 0
# Image enregistrée : image_2023-07-05_20-30_0.jpg
# image : 1
# Image enregistrée : image_2023-07-05_20-30_1.jpg
# image : 2
# Image enregistrée : image_2023-07-05_20-30_2.jpg
# image : 3
# Image enregistrée : image_2023-07-05_20-30_3.jpg
# image : 4
# Image enregistrée : image_2023-07-05_20-30_4.jpg
# image : 5
# Image enregistrée : image_2023-07-05_20-30_5.jpg
# image : 6
# Image enregistrée : image_2023-07-05_20-30_6.jpg
# image : 7
# Image enregistrée : image_2023-07-05_20-30_7.jpg
# image : 8
# Image enregistrée : image_2023-07-05_20-30_8.jpg
# image : 9
# Image enregistrée : image_2023-07-05_20-30_9.jpg
# image : 10
# Image enregistrée : image_2023-07-05_20-30_10.jpg
# image : 11
# Image enregistrée : image_2023-07-05_20-30_11.jpg
# image : 12
# Image enregistrée : image_2023-07-05_20-30_12.jpg
# image : 13
# Image enregistrée : image_2023-07-05_20-30_13.jpg
# image : 14
# Image enregistrée : image_2023-07-05_20-30_14.jpg
# image : 15
# image : 58
# Image enregistrée : image_2023-07-05_20-30_58.jpg
# image : 59
# Image enregistrée : image_2023-07-05_20-30_59.jpg
# image : 60
# Image enregistrée : image_2023-07-05_20-30_60.jpg
# image : 61
# Image enregistrée : image_2023-07-05_20-30_61.jpg
# image : 62
# Image enregistrée : image_2023-07-05_20-30_62.jpg
# image : 63
# Image enregistrée : image_2023-07-05_20-30_63.jpg
# image : 64
# Image enregistrée : image_2023-07-05_20-30_64.jpg
# image : 65
# Image enregistrée : image_2023-07-05_20-30_65.jpg
# image : 66
# Image enregistrée : image_2023-07-05_20-30_66.jpg
# image : 67
# Image enregistrée : image_2023-07-05_20-30_67.jpg
# image : 68
# Image enregistrée : image_2023-07-05_20-30_68.jpg
# image : 69
# Image enregistrée : image_2023-07-05_20-30_69.jpg
# image : 70
# Image enregistrée : image_2023-07-05_20-30_70.jpg
# image : 71
# Image enregistrée : image_2023-07-05_20-30_71.jpg
# image : 72
# Image enregistrée : image_2023-07-05_20-30_72.jpg
# image : 73
# Image enregistrée : image_2023-07-05_20-30_73.jpg
# image : 74
# Image enregistrée : image_2023-07-05_20-30_74.jpg
# image : 75
# Image enregistrée : image_2023-07-05_20-30_75.jpg
# image : 76
# Image enregistrée : image_2023-07-05_20-30_76.jpg
# image : 77
# Image enregistrée : image_2023-07-05_20-30_77.jpg
# image : 78
# Image enregistrée : image_2023-07-05_20-30_78.jpg
# image : 79
# Image enregistrée : image_2023-07-05_20-30_79.jpg
# image : 80
# Image enregistrée : image_2023-07-05_20-30_80.jpg
# image : 81
# Image enregistrée : image_2023-07-05_20-30_81.jpg
# image : 82
# Image enregistrée : image_2023-07-05_20-30_82.jpg
# image : 83
# Image enregistrée : image_2023-07-05_20-30_83.jpg
# image : 84
# Image enregistrée : image_2023-07-05_20-30_84.jpg
# image : 85
# Image enregistrée : image_2023-07-05_20-30_85.jpg
# image : 86
# Image enregistrée : image_2023-07-05_20-30_86.jpg
# image : 87
# Image enregistrée : image_2023-07-05_20-30_87.jpg
# image : 88
# Image enregistrée : image_2023-07-05_20-30_88.jpg
# image : 89
# Image enregistrée : image_2023-07-05_20-30_89.jpg
# image : 90
# Image enregistrée : image_2023-07-05_20-30_90.jpg
# HTTPSConnectionPool(host='www.explorevietnam.com.vn', port=443): Max retries exceeded with url: /hoi-an/wp-content/uploads/2018/08/dances-in-My-Son.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:997)')))
# image : 92
# Image enregistrée : image_2023-07-05_20-30_92.jpg
# image : 93
# Image enregistrée : image_2023-07-05_20-30_93.jpg
# image : 94
# Image enregistrée : image_2023-07-05_20-30_94.jpg
# image : 95
# Image enregistrée : image_2023-07-05_20-30_95.jpg
# image : 96
# Image enregistrée : image_2023-07-05_20-30_96.jpg
# image : 97
# Image enregistrée : image_2023-07-05_20-30_97.jpg
# image : 98
# Image enregistrée : image_2023-07-05_20-30_98.jpg
# image : 99
# Image enregistrée : image_2023-07-05_20-30_99.jpg
# requete terminée
