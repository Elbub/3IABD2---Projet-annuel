# %%
from serpapi import GoogleSearch
import json
import requests
# from environs import Env
from datetime import datetime


# env = Env()
# env.read_env()

# Clé d'API SerpApi
# API_KEY = env.str("SERPAPI_KEY")
api_key="4540644eb4bb34b2eb353bcbc8de301b18cff345ae3e5bb4d1669e0e4a001cfe"

def get_images(api_key, search: str, page: int = 1, pays_requete: str = "US"):
    # Paramètres de recherche
    params = {
        "api_key": api_key,
        "q": search,
        "engine": "google_images",
        "cc": pays_requete,
        "ijn": page,  # ce paramètre correspond à la page de google image à télécharger
    }

    # Appel de l'API SerpApi
    search = GoogleSearch(params)  # nous donne la réponse de l'appel api
    results = search.get_dict()  # JSON -> Python dict
    return results

    store_images(res, destination_folder[0])


def store_images(results, destination_folder: str):
    day = datetime.now()

    # Dossier de destination pour enregistrer les images
    destination_folder = f"../photos_brutes/{destination_folder}"

    # headers pour passer dans certains cas une sécurité qui bloque les algo de scrapping
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }
    if "error" not in results and "images_results" in results:
        images = results["images_results"]
        for i, image in enumerate(images):
            image_url = image["original"]
            if image_url:
                # num = i + 100 # penser à mettre la bonne centaine ici, cela a pour but de nommer différemment nos images
                file_name = (
                    f"image_{day.strftime('%Y-%m-%d_%H-%M')}_{i}.jpg"  # nom du fichier
                )
                try:
                    response = requests.get(image_url, headers=headers)
                    # Enregistrer l'image dans le dossier de destination
                    if response.status_code == 200:
                        print(f"image : {i}")
                        with open(f"{destination_folder}/{file_name}", "wb") as file:
                            file.write(response.content)
                            print(f"Image enregistrée : {file_name}")
                    else:
                        print(f"Echec du téléchargement de l'image : {image_url}")
                except Exception as e:
                    print(e)

# %%
    res = get_images(api_key, "greek ruins by night", 2, "US")

# %%
    destination_folder = ["rome_grece", "amerique_sud", "asie_sud_est"]
    store_images(res, destination_folder[0])
# Out:
# image : 0
# Image enregistrée : image_2023-06-11_20-18_0.jpg
# image : 1
# Image enregistrée : image_2023-06-11_20-18_1.jpg
# image : 2
# Image enregistrée : image_2023-06-11_20-18_2.jpg
# image : 3
# Image enregistrée : image_2023-06-11_20-18_3.jpg
# image : 4
# Image enregistrée : image_2023-06-11_20-18_4.jpg
# image : 5
# Image enregistrée : image_2023-06-11_20-18_5.jpg
# image : 6
# Image enregistrée : image_2023-06-11_20-18_6.jpg
# image : 7
# Image enregistrée : image_2023-06-11_20-18_7.jpg
# image : 8
# Image enregistrée : image_2023-06-11_20-18_8.jpg
# image : 9
# Image enregistrée : image_2023-06-11_20-18_9.jpg
# image : 10
# Image enregistrée : image_2023-06-11_20-18_10.jpg
# image : 11
# Image enregistrée : image_2023-06-11_20-18_11.jpg
# image : 12
# Image enregistrée : image_2023-06-11_20-18_12.jpg
# image : 13
# Image enregistrée : image_2023-06-11_20-18_13.jpg
# image : 14
# Image enregistrée : image_2023-06-11_20-18_14.jpg
# image : 15
# Image enregistrée : image_2023-06-11_20-18_15.jpg
# image : 16
# Image enregistrée : image_2023-06-11_20-18_16.jpg
# image : 17
# Image enregistrée : image_2023-06-11_20-18_17.jpg
# image : 18
# Image enregistrée : image_2023-06-11_20-18_18.jpg
# Echec du téléchargement de l'image : https://scontent-atl3-1.cdninstagram.com/v/t51.2885-15/348870734_944592380125869_3312183588280791326_n.jpg?stp=dst-jpg_e35&_nc_ht=scontent